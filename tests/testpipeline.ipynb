# %%
# test_dataset.py

from mmdet3d.registry import DATASETS
from mmengine.config import Config
#from mmengine.registry import build_dataset
from mmdet3d.registry import MODELS
from mmengine.registry import build_model_from_cfg

# %%
import os
# Print current working directory
print("Current Directory:", os.getcwd())
# Change to a new directory
os.chdir('/u/student/2023/cs21m23p100001/mmdetection3d')
# Verify the change
print("New Directory:", os.getcwd())

# %%
cfg = Config.fromfile('projects/myfusion/configs/my_fusion_transformer_resnet18_pointpillerscatter.py')
print(MODELS.module_dict.keys())

# %%
# test_dataset.py
from mmdet3d.registry import DATASETS

dataset = DATASETS.build(cfg.train_dataloader['dataset'])
print("Loaded dataset:", dataset)
#print(f"✅ Checking image path: {type(dataset['img_path'])}")

#print(len(dataset))
print(dir(dataset))
print(type(dataset[0]))

# %%
sample = dataset[0]
print(sample.keys())
print("datasamples", sample['data_samples'].keys())
print("inputs", sample['inputs'].keys())

# %%
print("Testing dataset:")
sample = dataset[0]
# batch_inputs expects a dict with keys 'img' and 'points'
batch_inputs = {
    'img': sample['inputs']['img'].unsqueeze(0),  # Add batch dim: [1, C, H, W]
    'points': [sample['inputs']['points']]        # Keep points in a list for batch
}

# %%
model = MODELS.build(cfg.model)
print("Loaded model:", model)
print(dir(model))

# %%
# Ensure batch_inputs and batch_data_samples are prepared as per the model's requirements
# batch_inputs is already defined in a previous cell

# batch_data_samples is a list of Det3DDataSample
batch_data_samples = [sample['data_samples']]

# Forward pass through the model
predictions = model(batch_inputs)

# Print the predictions
print("Model predictions:", predictions)

# %%
# batch_data_samples is a list of Det3DDataSample
batch_data_samples = [sample['data_samples']]


pred = model(sample)
print("output ", pred)
# Out:
# batch data sample None
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[18], line 5
#       1 # batch_data_samples is a list of Det3DDataSample
#       2 batch_data_samples = [sample['data_samples']]
# ----> 5 pred = model(sample)
#       6 print("output ", pred)
#
# File ~/miniconda3/envs/openmmlab/lib/python3.8/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/openmmlab/lib/python3.8/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/mmdetection3d/mmdet3d/models/detectors/base.py:88, in Base3DDetector.forward(self, inputs, data_samples, mode, **kwargs)
#      86         return self.predict(inputs, data_samples, **kwargs)
#      87 elif mode == 'tensor':
# ---> 88     return self._forward(inputs, data_samples, **kwargs)
#      89 else:
#      90     raise RuntimeError(f'Invalid mode "{mode}". '
#      91                        'Only supports loss, predict and tensor mode')
#
# File ~/mmdetection3d/projects/myfusion/fusion/my_fusion.py:100, in MyFusionTransformer._forward(self, batch_inputs, batch_data_samples)
#      98 lidar = batch_inputs.get('points', None)#batch_inputs['inputs']['points']
#      99 print("batch data sample",batch_data_samples)
# --> 100 voxels, coors, num_points = self.data_preprocessor(batch_inputs)
#     101 #img_metas = [data.metainfo for data in batch_data_samples]
#     103 img_feats, lidar_feats = self.extract_feat(img, lidar)
#
# File ~/miniconda3/envs/openmmlab/lib/python3.8/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/openmmlab/lib/python3.8/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/mmdetection3d/mmdet3d/models/data_preprocessors/data_preprocessor.py:152, in Det3DDataPreprocessor.forward(self, data, training)
#     149     return aug_batch_data
#     151 else:
# --> 152     return self.simple_process(data, training)
#
# File ~/mmdetection3d/mmdet3d/models/data_preprocessors/data_preprocessor.py:168, in Det3DDataPreprocessor.simple_process(self, data, training)
#     155 """Perform normalization, padding and bgr2rgb conversion for img data
#     156 based on ``BaseDataPreprocessor``, and voxelize point cloud if `voxel`
#     157 is set to be True.
#    (...)
#     165     dict: Data in the same format as the model input.
#     166 """
#     167 if 'img' in data['inputs']:
# --> 168     batch_pad_shape = self._get_pad_shape(data)
#     170 data = self.collate_data(data)
#     171 inputs, data_samples = data['inputs'], data['data_samples']
#
# File ~/mmdetection3d/mmdet3d/models/data_preprocessors/data_preprocessor.py:324, in Det3DDataPreprocessor._get_pad_shape(self, data)
#     322 # Process data with `default_collate`.
#     323 elif isinstance(_batch_inputs, torch.Tensor):
# --> 324     assert _batch_inputs.dim() == 4, (
#     325         'The input of `ImgDataPreprocessor` should be a NCHW tensor '
#     326         'or a list of tensor, but got a tensor with shape: '
#     327         f'{_batch_inputs.shape}')
#     328     pad_h = int(
#     329         np.ceil(_batch_inputs.shape[1] /
#     330                 self.pad_size_divisor)) * self.pad_size_divisor
#     331     pad_w = int(
#     332         np.ceil(_batch_inputs.shape[2] /
#     333                 self.pad_size_divisor)) * self.pad_size_divisor
#
# AssertionError: The input of `ImgDataPreprocessor` should be a NCHW tensor or a list of tensor, but got a tensor with shape: torch.Size([3, 384, 1280])
